# %% [markdown]
# # 🇱🇰 Sri Lanka Road Network — AA-to-AA Junction Shortest-Path Distance Analysis
#
# This notebook performs a focused analysis of shortest-path distances **between Class AA junctions only** — i.e. junctions where two or more Class AA (national trunk) roads meet. Unlike the full-network experiment, which routes between every AA/B junction, this experiment restricts both the source and target sets to **AA-AA junctions**, isolating the connectivity characteristics of Sri Lanka's primary national road backbone.
#
# The notebook imports the CSV datasets exported by `sri_lanka_roads_interactive.ipynb` and constructs a weighted graph representing Sri Lanka's **full** road network (so that routing between AA-AA junctions can use any underlying road, not just AA-tagged segments). It then filters the junction set down to `is_aa_aa_junction == True` before running the shortest-path computation.
#
# The experiment computes the shortest-path distance between every reachable pair of AA-AA junctions, producing statistics that describe the structure, accessibility, and connectivity of the AA road backbone specifically. These results are directly comparable to the full-network baseline produced by `experiment_all_junction_distance.ipynb`.
#
# ## Methodology
#
# 1. Construct an undirected, weighted graph from the exported **full** Sri Lankan road network.
#    - Nodes represent every road junction and intersection (not just AA junctions) — needed so that AA-AA routes can pass through non-AA roads.
#    - Edges represent road segments weighted by physical length (meters).
#
# 2. Load the AA/B junction classification table and filter to junctions flagged `is_aa_aa_junction == True` (i.e. where 2+ Class AA roads meet).
#
# 3. For every AA-AA junction, execute Dijkstra's shortest-path algorithm to every other AA-AA junction.
#
# 4. Record the shortest-path distances and compute AA-AA-specific statistics, including:
#    - Average shortest-path distance
#    - Median distance
#    - Minimum and maximum distances
#    - Standard deviation
#    - Reachability statistics
#
# 5. Generate visualizations illustrating the spatial characteristics of the AA-AA subnetwork, including:
#    - Histogram of shortest-path distances
#    - Box plot
#    - Cumulative distribution function (CDF)
#    - AA-AA junction accessibility (centrality) heat map
#
# 6. Export per-junction metrics and summary statistics for comparison with the full-network experiment.
#
# ## Required Input Files
#
# The following datasets are produced by the export sections of `sri_lanka_roads_interactive.ipynb` and should be located in `./data/` (or the directory specified by `DATA_DIR`):
#
# - `sri_lanka_full_network_nodes.csv` — All nodes in the road network (`node_id`, `latitude`, `longitude`, `street_count`)
# - `sri_lanka_full_network_edges.csv` — All road segments (`u`, `v`, `length_m`, ...)
# - `sri_lanka_rda_aa_b_junctions.csv` — AA/B junction classification, including the `is_aa_aa_junction` flag used to build the AA-AA junction set

# %%
# ── 0. Dependencies & Configuration ──────────────────────────────────────────
import os
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors

import warnings
warnings.filterwarnings('ignore')

# Folder containing the CSVs exported from the main notebook
DATA_DIR = "data"          # <- change this if your CSVs live elsewhere (e.g. "outputs")
OUTPUT_DIR = "outputs_aa_aa"
os.makedirs(OUTPUT_DIR, exist_ok=True)

NODES_PATH        = os.path.join(DATA_DIR, "sri_lanka_full_network_nodes.csv")
EDGES_PATH        = os.path.join(DATA_DIR, "sri_lanka_full_network_edges.csv")
AA_JUNCTIONS_PATH = os.path.join(DATA_DIR, "sri_lanka_rda_aa_b_junctions.csv")

for p in [NODES_PATH, EDGES_PATH, AA_JUNCTIONS_PATH]:
    status = "✅ found" if os.path.exists(p) else "❌ MISSING"
    print(f"{status:12s} {p}")

print()
print("If any file is missing: run the main notebook's Section 7a / Section 9 export cells,")
print(f"then copy its outputs/ CSVs into '{DATA_DIR}/' (or update DATA_DIR above).")
# Out:
# ✅ found      data\sri_lanka_full_network_nodes.csv
# ✅ found      data\sri_lanka_full_network_edges.csv
# ✅ found      data\sri_lanka_rda_aa_b_junctions.csv
#
# If any file is missing: run the main notebook's Section 7a / Section 9 export cells,
# then copy its outputs/ CSVs into 'data/' (or update DATA_DIR above).

# %%
# ── 1. Load exported data & filter to AA-AA junctions ─────────────────────
df_nodes           = pd.read_csv(NODES_PATH)
df_edges           = pd.read_csv(EDGES_PATH)
df_junctions_all_aa = pd.read_csv(AA_JUNCTIONS_PATH)

# Keep only junctions where 2+ Class AA roads meet (AA-AA junctions)
df_junctions = df_junctions_all_aa[df_junctions_all_aa['is_aa_aa_junction'] == True].copy()

print(f"Full network nodes      : {len(df_nodes):,}")
print(f"Full network edges      : {len(df_edges):,}")
print(f"All AA/B junctions      : {len(df_junctions_all_aa):,}")
print(f"AA-AA junctions (kept)  : {len(df_junctions):,}")

df_junctions.head()
# Out:
# Full network nodes      : 5,557
# Full network edges      : 12,031
# All AA/B junctions      : 2,017
# AA-AA junctions (kept)  : 83
#       node_id  latitude  longitude  street_count  n_aa_roads aa_roads  \
# 11  258029156  7.264124  80.592942             3           2    A1;A5
# 15   44265234  6.732073  81.101954             3           2    A2;A4
# 19  603240642  6.731658  81.099805             4           2   A23;A4
# 28   49364356  6.873478  81.031248             3           2  A16;A23
# 58   59947552  6.032158  80.239635             3           2   A17;A2
#
#    junction_type  is_aa_aa_junction  is_aa_any_junction  is_b_road
# 11         AA-AA               True                True      False
# 15         AA-AA               True                True      False
# 19         AA-AA               True                True      False
# 28         AA-AA               True                True      False
# 58         AA-AA               True                True      False

# %% [markdown]
# ---
# ## 2. Build the Graph
#
# Undirected, weighted graph. Nodes are road junctions/intersections; edges are road segments
# weighted by physical length in meters (`length_m`). OSMnx stores each two-way road as two
# directed edges (u→v and v→u) — building an undirected `networkx.Graph` and keeping the
# **minimum** length seen for any (u, v) pair de-duplicates this automatically, and also collapses
# any parallel multi-edges down to the shortest physical connection between the two junctions.

# %%
# ── 2. Build undirected weighted graph ───────────────────────────────────────
G = nx.Graph()

# Node attributes: lat/lon + any available metadata
node_attrs = df_nodes.set_index('node_id').to_dict(orient='index')
for node_id, attrs in node_attrs.items():
    G.add_node(node_id, **attrs)

# Edges: keep the minimum length_m for any duplicate / parallel (u, v) pair
edge_min = (
    df_edges
    .dropna(subset=['u', 'v', 'length_m'])
    .groupby(['u', 'v'], as_index=False)['length_m']
    .min()
)

n_edges_added = 0
n_edges_skipped = 0
for _, row in edge_min.iterrows():
    u, v, w = row['u'], row['v'], row['length_m']
    if u == v or w <= 0:
        n_edges_skipped += 1
        continue
    if G.has_edge(u, v):
        # keep the shorter of the two directions if both appeared
        G[u][v]['weight'] = min(G[u][v]['weight'], w)
    else:
        G.add_edge(u, v, weight=w)
        n_edges_added += 1

print(f"Graph built: {G.number_of_nodes():,} nodes, {G.number_of_edges():,} edges")
print(f"  edges skipped (self-loops / zero-length): {n_edges_skipped:,}")

# Restrict the AA-AA junction set to nodes that actually exist in the graph
junction_ids = [j for j in df_junctions['node_id'].unique() if j in G]
missing_junctions = len(df_junctions['node_id'].unique()) - len(junction_ids)
print(f"\nAA-AA junctions present in graph: {len(junction_ids):,}"
      f"  ({missing_junctions} junction IDs from the CSV were not found in the graph and were dropped)")
# Out:
# Graph built: 5,557 nodes, 8,326 edges
#   edges skipped (self-loops / zero-length): 1
#
# AA-AA junctions present in graph: 83  (0 junction IDs from the CSV were not found in the graph and were dropped)

# %% [markdown]
# ---
# ## 3. Network-Wide Statistics

# %%
# ── 3. Network-wide statistics ────────────────────────────────────────────
n_nodes = G.number_of_nodes()
n_edges = G.number_of_edges()
components = list(nx.connected_components(G))
n_components = len(components)
largest_cc = max(components, key=len)

density = nx.density(G)
avg_degree = (2 * n_edges) / n_nodes if n_nodes else 0.0

network_stats = {
    "Number of junctions (nodes)":    n_nodes,
    "Number of road segments (edges)": n_edges,
    "Number of connected components":  n_components,
    "Largest component size":          len(largest_cc),
    "Graph density":                   density,
    "Average node degree":             avg_degree,
}

print("── Network-wide statistics ──")
for k, v in network_stats.items():
    print(f"  {k:35s}: {v:,.6f}" if isinstance(v, float) else f"  {k:35s}: {v:,}")
# Out:
# ── Network-wide statistics ──
#   Number of junctions (nodes)        : 5,557
#   Number of road segments (edges)    : 8,326
#   Number of connected components     : 19
#   Largest component size             : 5,517
#   Graph density                      : 0.000539
#   Average node degree                : 2.996581

# %% [markdown]
# ---
# ## 4. Experiment — Full Network Junction-to-Junction Shortest-Path Analysis
#
# For every road junction in the Sri Lankan road network, Dijkstra's algorithm is executed to compute the shortest-path distance to every other reachable junction. The road network is represented as an undirected, weighted graph, where junctions are nodes, road segments are edges, and edge weights correspond to physical road lengths (meters).
#
# This repeated single-source shortest-path approach has a computational complexity of **O(V · (E log V))** and is preferred over Floyd–Warshall due to the large size and sparse nature of the road network.

# %%
# ── 4. Run Dijkstra from every AA-AA junction (AA -> AA) ─────────────────────
junction_set = set(junction_ids)

pair_records = []          # one row per ordered (AA, AA') reachable pair
per_junction_records = []  # one row per AA-AA junction

for i, source in enumerate(junction_ids):
    # Single-source Dijkstra over the full graph
    dist_map, path_map = nx.single_source_dijkstra(G, source, weight='weight')

    reachable_dists = []
    reachable_hops  = []
    for target in junction_ids:
        if target == source:
            continue
        if target in dist_map:
            d = dist_map[target]
            hops = len(path_map[target]) - 1
            pair_records.append((source, target, d, hops))
            reachable_dists.append(d)
            reachable_hops.append(hops)

    n_reachable   = len(reachable_dists)
    n_unreachable = (len(junction_ids) - 1) - n_reachable

    per_junction_records.append({
        "junction_id":       source,
        "latitude":          G.nodes[source].get("latitude", np.nan),
        "longitude":         G.nodes[source].get("longitude", np.nan),
        "reachable_nodes":   n_reachable,
        "unreachable_nodes": n_unreachable,
        "average_distance":  float(np.mean(reachable_dists)) if reachable_dists else np.nan,
        "maximum_distance":  float(np.max(reachable_dists))  if reachable_dists else np.nan,
        "average_hops":      float(np.mean(reachable_hops))  if reachable_hops  else np.nan,
    })

    if (i + 1) % 200 == 0 or (i + 1) == len(junction_ids):
        print(f"  processed {i + 1:,} / {len(junction_ids):,} source AA-AA junctions...")

df_pairs = pd.DataFrame(pair_records, columns=["source", "target", "distance_m", "hops"])
df_per_junction = pd.DataFrame(per_junction_records)

print(f"\n✅ Computed shortest paths for {len(junction_ids):,} source AA-AA junctions")
print(f"   Total reachable ordered pairs: {len(df_pairs):,}")
# Out:
#   processed 83 / 83 source AA-AA junctions...
#
# ✅ Computed shortest paths for 83 source AA-AA junctions
#    Total reachable ordered pairs: 6,806

# %% [markdown]
# ---
# ## 5. Shortest-Path Statistics
#
# Self-distances are excluded by construction (the loop above skips `target == source`).
# Unreachable pairs are reported separately rather than included in the distance statistics.

# %%
# ── 5. Shortest-path statistics ───────────────────────────────────────────
distances_m = df_pairs["distance_m"].values
hops = df_pairs["hops"].values

n_possible_ordered_pairs = len(junction_ids) * (len(junction_ids) - 1)
n_reachable_pairs = len(df_pairs)
n_unreachable_pairs = n_possible_ordered_pairs - n_reachable_pairs

path_stats = {
    "Mean shortest-path distance (m)":   float(np.mean(distances_m)),
    "Median shortest-path distance (m)": float(np.median(distances_m)),
    "Minimum shortest-path distance (m)": float(np.min(distances_m)),
    "Maximum shortest-path distance (m)": float(np.max(distances_m)),
    "Standard deviation (m)":            float(np.std(distances_m)),
    "95th percentile distance (m)":      float(np.percentile(distances_m, 95)),
    "Mean hop count":                    float(np.mean(hops)),
    "Graph diameter (max shortest path, m)": float(np.max(distances_m)),
}

print("── Shortest-path statistics (AA-AA junction -> AA-AA junction, self-distances excluded) ──")
for k, v in path_stats.items():
    print(f"  {k:42s}: {v:,.2f}")

print()
print(f"  Reachable ordered pairs   : {n_reachable_pairs:,} / {n_possible_ordered_pairs:,}"
      f"  ({100 * n_reachable_pairs / n_possible_ordered_pairs:.2f}%)")
print(f"  Unreachable ordered pairs : {n_unreachable_pairs:,}"
      f"  ({100 * n_unreachable_pairs / n_possible_ordered_pairs:.2f}%)")
# Out:
# ── Shortest-path statistics (AA-AA junction -> AA-AA junction, self-distances excluded) ──
#   Mean shortest-path distance (m)           : 182,988.98
#   Median shortest-path distance (m)         : 179,590.08
#   Minimum shortest-path distance (m)        : 5.89
#   Maximum shortest-path distance (m)        : 512,229.04
#   Standard deviation (m)                    : 100,787.65
#   95th percentile distance (m)              : 355,430.41
#   Mean hop count                            : 81.61
#   Graph diameter (max shortest path, m)     : 512,229.04
#
#   Reachable ordered pairs   : 6,806 / 6,806  (100.00%)
#   Unreachable ordered pairs : 0  (0.00%)

# %% [markdown]
# ---
# ## 6. Per-Junction Statistics (Centrality Proxy)
#
# `average_distance` and `maximum_distance` per junction were already computed during the Dijkstra
# pass in Section 4. Lower average distance ⇒ more central; higher ⇒ more remote/isolated.

# %%
# ── 6. Per-junction statistics preview ───────────────────────────────────────
df_per_junction_sorted = df_per_junction.sort_values("average_distance")

print("Most central AA-AA junctions (lowest average distance to all other AA-AA junctions):")
display(df_per_junction_sorted.head(10))

print("\nMost remote/isolated AA-AA junctions (highest average distance):")
display(df_per_junction_sorted.dropna(subset=["average_distance"]).tail(10))
# Out:
# Most central AA-AA junctions (lowest average distance to all other AA-AA junctions):
#     junction_id  latitude  longitude  reachable_nodes  unreachable_nodes  \
# 57   6289622879  7.874077  80.651088               82                  0
# 50   1981147403  7.885130  80.651621               82                  0
# 18   7599684152  7.885072  80.651668               82                  0
# 69   9513937138  7.487109  80.365072               82                  0
# 81   9568699375  7.487044  80.365047               82                  0
# 71   4944055634  7.487134  80.364992               82                  0
# 70   4944055508  7.487073  80.364967               82                  0
# 9    8014319683  8.127337  80.562747               82                  0
# 76   8014319682  8.127311  80.562666               82                  0
# 59   3088508720  7.322347  80.624795               82                  0
#
#     average_distance  maximum_distance  average_hops
# 57     130418.004786     285832.177100     61.219512
# 50     130656.467421     287158.502932     60.439024
# 18     130659.420316     287165.022281     61.585366
# 69     134691.089839     293634.867633     62.890244
# 81     134692.337276     293642.541049     63.012195
# 71     134694.664140     293644.134386     63.524390
# 70     134695.886943     293651.438933     63.646341
# 9      138743.771965     316084.681799     64.048780
# 76     138744.961790     316084.751533     64.182927
# 59     138799.154298     304853.523841     68.390244
# Most remote/isolated AA-AA junctions (highest average distance):
#     junction_id  latitude  longitude  reachable_nodes  unreachable_nodes  \
# 38   7042347632  9.436304  80.407659               82                  0
# 37   1735981103  9.436373  80.407658               82                  0
# 28   7042347620  9.436550  80.407655               82                  0
# 46   1985676681  6.113641  80.991506               82                  0
# 4      59947552  6.032158  80.239635               82                  0
# 6      98554769  6.090296  80.476194               82                  0
# 17   4136824664  9.662059  80.081689               82                  0
# 64   3474422106  9.662146  80.081620               82                  0
# 65   4136824662  9.661981  80.081524               82                  0
# 20   4136824665  9.662098  80.081465               82                  0
#
#     average_distance  maximum_distance  average_hops
# 38     236473.244115     467215.609002     85.939024
# 37     236479.789191     467223.273959     86.792683
# 28     236497.090725     467242.863908     87.670732
# 46     259830.590381     512229.042816     96.036585
# 4      260522.570028     466262.513267    178.768293
# 6      270249.150096     496240.623653    114.024390
# 17     278887.105562     512200.703765     83.451220
# 64     278898.920151     512212.969046     84.414634
# 65     278900.534299     512214.586996     83.451220
# 20     278914.405856     512229.042816     84.414634

# %% [markdown]
# ---
# ## 7. Visualizations
#
# ### 7a. Histogram — Distribution of Shortest-Path Distances

# %%
# ── 7a. Histogram ─────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(distances_m / 1000, bins=60, color="#2980b9", edgecolor="white", alpha=0.85)
ax.axvline(np.mean(distances_m) / 1000, color="#e74c3c", linestyle="--", linewidth=2,
           label=f"Mean = {np.mean(distances_m)/1000:.1f} km")
ax.axvline(np.median(distances_m) / 1000, color="#27ae60", linestyle="--", linewidth=2,
           label=f"Median = {np.median(distances_m)/1000:.1f} km")
ax.set_xlabel("Shortest-path distance (km)")
ax.set_ylabel("Number of junction pairs")
ax.set_title("Distribution of AA-AA Junction Shortest-Path Distances", fontweight="bold")
ax.legend()
ax.grid(axis="y", alpha=0.3)
ax.spines[["top", "right"]].set_visible(False)
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/chart_distance_histogram.png", dpi=150, bbox_inches="tight")
plt.show()
print(f"✅ Saved {OUTPUT_DIR}/chart_distance_histogram.png")
# Out:
# ✅ Saved outputs_aa_aa/chart_distance_histogram.png

# %% [markdown]
# ### 7b. Box Plot — Shortest-Path Distance Distribution

# %%
# ── 7b. Box plot ──────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(8, 6))
bp = ax.boxplot(distances_m / 1000, vert=True, patch_artist=True, widths=0.4,
                 showfliers=True, flierprops=dict(marker='o', markersize=2, alpha=0.3))
for box in bp['boxes']:
    box.set_facecolor("#8e44ad")
    box.set_alpha(0.7)
ax.set_ylabel("Shortest-path distance (km)")
ax.set_xticks([1])
ax.set_xticklabels(["AA-AA junction pairs"])
ax.set_title("AA-AA Shortest-Path Distance — Box Plot", fontweight="bold")
ax.grid(axis="y", alpha=0.3)
ax.spines[["top", "right"]].set_visible(False)
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/chart_distance_boxplot.png", dpi=150, bbox_inches="tight")
plt.show()
print(f"✅ Saved {OUTPUT_DIR}/chart_distance_boxplot.png")
# Out:
# ✅ Saved outputs_aa_aa/chart_distance_boxplot.png

# %% [markdown]
# ### 7c. Heat Map — Junction Centrality
#
# Junctions colored by their average distance to all other junctions:
# 🟢 green = very central, 🟡 yellow = average, 🔴 red = isolated.

# %%
# ── 7c. Centrality heat map (static, matplotlib) ─────────────────────────────
plot_df = df_per_junction.dropna(subset=["average_distance", "latitude", "longitude"])

fig, ax = plt.subplots(figsize=(11, 14), facecolor="#0d1117")
ax.set_facecolor("#0d1117")

norm = mcolors.Normalize(vmin=plot_df["average_distance"].min(),
                          vmax=plot_df["average_distance"].max())
cmap = cm.get_cmap("RdYlGn_r")   # green (low/central) -> red (high/isolated)

sc = ax.scatter(plot_df["longitude"], plot_df["latitude"],
                 c=plot_df["average_distance"], cmap=cmap, norm=norm,
                 s=18, alpha=0.9, edgecolors="none")

cbar = plt.colorbar(sc, ax=ax, shrink=0.6)
cbar.set_label("Average distance to all other junctions (m)", color="white")
cbar.ax.yaxis.set_tick_params(color="white")
plt.setp(cbar.ax.yaxis.get_ticklabels(), color="white")

ax.set_title("AA-AA Junction Centrality Heat Map\n(green = central, red = isolated)",
             color="white", fontweight="bold", fontsize=13)
ax.set_xticks([]); ax.set_yticks([])
for spine in ax.spines.values():
    spine.set_visible(False)
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/chart_centrality_heatmap.png", dpi=150,
            bbox_inches="tight", facecolor=fig.get_facecolor())
plt.show()
print(f"✅ Saved {OUTPUT_DIR}/chart_centrality_heatmap.png")
# Out:
# ✅ Saved outputs_aa_aa/chart_centrality_heatmap.png

# %% [markdown]
# ### 7c (interactive). Centrality Heat Map — Folium
#
# An interactive Leaflet version of the same centrality heat map: click any junction to see its
# exact average and maximum distance.

# %%
# ── 7c-interactive. Folium centrality map ────────────────────────────────────
import folium
import matplotlib.colors as mcolors

m = folium.Map(
    location=[plot_df["latitude"].mean(), plot_df["longitude"].mean()],
    zoom_start=8, tiles="CartoDB dark_matter", control_scale=True,
)

vmin, vmax = plot_df["average_distance"].min(), plot_df["average_distance"].max()
cmap = cm.get_cmap("RdYlGn_r")

for _, row in plot_df.iterrows():
    frac = (row["average_distance"] - vmin) / (vmax - vmin) if vmax > vmin else 0.5
    color = mcolors.to_hex(cmap(frac))
    folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=4, color=color, weight=1, fill=True, fill_color=color, fill_opacity=0.85,
        popup=(f"<b>Junction {int(row['junction_id'])}</b><br>"
               f"Avg distance: {row['average_distance']/1000:.1f} km<br>"
               f"Max distance: {row['maximum_distance']/1000:.1f} km<br>"
               f"Reachable junctions: {int(row['reachable_nodes'])}"),
    ).add_to(m)

interactive_map_path = f"{OUTPUT_DIR}/junction_centrality_map.html"
m.save(interactive_map_path)
print(f"✅ Interactive centrality map saved -> {interactive_map_path}")
m
# Out:
# ✅ Interactive centrality map saved -> outputs_aa_aa/junction_centrality_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcc34591b8ccf0b728af2751126c9829 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcc34591b8ccf0b728af2751126c9829&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcc34591b8ccf0b728af2751126c9829 = L.map(
#                 &quot;map_dcc34591b8ccf0b728af2751126c9829&quot;,
#                 {
#                     center: [7.729984518072289, 80.56735532530121],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_dcc34591b8ccf0b728af2751126c9829);
#
#
#
#
#
#             var tile_layer_04b3c91abbf300dbe8bf28e96dfe9711 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04b3c91abbf300dbe8bf28e96dfe9711.addTo(map_dcc34591b8ccf0b728af2751126c9829);
#
#
#             var circle_marker_93842eed8aded6b94f803877f73fda21 = L.circleMarker(
#                 [7.264124, 80.592942],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#108647&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#108647&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dcc34591b8ccf0b728af2751126c9829);
#
#
#         var popup_e00945c8524753a9fc5a3a12156054c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f05dbc1c74977febdd9d0062841a608 = $(`&lt;div id=&quot;html_5f05dbc1c74977febdd9d0062841a608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Junction 258029156&lt;/b&gt;&lt;br&gt;Avg distance: 140.3 km&lt;br&gt;Max distance: 314.0 km&lt;br&gt;Reachable junctions: 82&lt;/div&gt;`)[0];
#                 popup_e00945c8524753a9fc5a3a12156054c4.setContent(html_5f05dbc1c74977febdd9d0062841a608);
#
#
#
#         circle_marker_93842eed8aded6b94f803877f73fda21.bindPopup(popup_e00945c8524753a9fc5a3a12156054c4)
#         ;
#
#
#
#
#             var circle_marker_dec8d7afd3c440d30e672720da686182 = L.circleMarker(
#                 [6.732073, 81.101954],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff5ae&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff5ae&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dcc34591b8ccf0b728af2751126c9829);
#
#
#         var popup_b78472d85c0016a34afb241a731d0ef9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1b90db562e21fe4d6c3bab724281cbd = $(`&lt;div id=&quot;html_a1b90db562e21fe4d6c3bab724281cbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Junction 44265234&lt;/b&gt;&lt;br&gt;Avg distance: 209.4 km&lt;br&gt;Max distance: 431.2 km&lt;br&gt;Reachable junctions: 82&lt;/div&gt;`)[0];
#                 popup_b78472d85c0016a34afb241a731d0ef9.setContent(html_a1b90db562e21fe4d6c3bab724281cbd);
#
#
#
#         circle_marker_dec8d7afd3c440d30e672720da686182.bindPopup(popup_b78472d85c0016a34afb241a731d0ef9)
#         ;
#
#
#
#
#             var circle_marker_b1b80ddce9eab3f123818289c9be8f84 = L.circleMarker(
#                 [6.731658, 81.099805],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff5ae&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff5ae&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_dcc34591b8ccf0b728af2751126c9829);
#
#
#         var popup_c10764310106c3a7f5e5f439eea63238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7feaca7520f2a1f8a019a73d7216972e = $(`&lt;div id=&quot;html_7fea

# %% [markdown]
# ### 7d. Cumulative Distribution — Junction Pairs vs. Shortest-Path Distance

# %%
# ── 7d. Cumulative distribution ───────────────────────────────────────────
sorted_d = np.sort(distances_m) / 1000
cum_pct = np.arange(1, len(sorted_d) + 1) / len(sorted_d) * 100

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(sorted_d, cum_pct, color="#16a085", linewidth=2)
ax.fill_between(sorted_d, cum_pct, alpha=0.15, color="#16a085")
ax.axhline(95, color="#e74c3c", linestyle="--", linewidth=1,
           label=f"95th percentile = {path_stats['95th percentile distance (m)']/1000:.1f} km")
ax.set_xlabel("Shortest-path distance (km)")
ax.set_ylabel("Cumulative percentage of junction pairs (%)")
ax.set_title("Cumulative Distribution of AA-AA Junction Distances", fontweight="bold")
ax.legend()
ax.grid(alpha=0.3)
ax.spines[["top", "right"]].set_visible(False)
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/chart_cumulative_distribution.png", dpi=150, bbox_inches="tight")
plt.show()
print(f"✅ Saved {OUTPUT_DIR}/chart_cumulative_distribution.png")
# Out:
# ✅ Saved outputs_aa_aa/chart_cumulative_distribution.png

# %% [markdown]
# ---
# ## 8. Outputs
#
# ### 8a. Per-Junction CSV

# %%
# ── 8a. Per-junction CSV ──────────────────────────────────────────────────
csv_export = df_per_junction[[
    "junction_id", "latitude", "longitude",
    "reachable_nodes", "average_distance", "maximum_distance",
]].rename(columns={"junction_id": "junction_id"})
csv_export = csv_export.round({"latitude": 6, "longitude": 6,
                                "average_distance": 2, "maximum_distance": 2})

per_junction_path = f"{OUTPUT_DIR}/aa_aa_junction_distance_stats.csv"
csv_export.to_csv(per_junction_path, index=False)
print(f"✅ Per-junction CSV -> {per_junction_path}  ({len(csv_export):,} rows)")

# Also save the raw pairwise distance table (useful for later experiments,
# e.g. betweenness centrality / robustness simulations)
pairs_path = f"{OUTPUT_DIR}/aa_aa_junction_pairwise_distances.csv"
df_pairs.to_csv(pairs_path, index=False)
print(f"✅ Pairwise distance table -> {pairs_path}  ({len(df_pairs):,} rows)")
# Out:
# ✅ Per-junction CSV -> outputs_aa_aa/aa_aa_junction_distance_stats.csv  (83 rows)
# ✅ Pairwise distance table -> outputs_aa_aa/aa_aa_junction_pairwise_distances.csv  (6,806 rows)

# %% [markdown]
# ### 8b. Summary Report

# %%
# ── 8b. Summary report ────────────────────────────────────────────────────
print("=" * 65)
print("  SRI LANKA ROAD NETWORK — AA-TO-AA JUNCTION DISTANCE EXPERIMENT")
print("=" * 65)
print()
print(f"  Nodes (full graph, used for routing) : {n_nodes:,}")
print(f"  Edges (road segments, full graph)    : {n_edges:,}")
print(f"  Connected components (full graph)    : {n_components:,}")
print(f"  Average degree (full graph)          : {avg_degree:.3f}")
print(f"  Graph density (full graph)           : {density:.6f}")
print()
print(f"  AA-AA junctions analysed       : {len(junction_ids):,}")
print()
print(f"  Average shortest-path distance : {path_stats['Mean shortest-path distance (m)']/1000:.2f} km")
print(f"  Median distance                : {path_stats['Median shortest-path distance (m)']/1000:.2f} km")
print(f"  Maximum distance               : {path_stats['Maximum shortest-path distance (m)']/1000:.2f} km")
print(f"  Minimum distance               : {path_stats['Minimum shortest-path distance (m)']/1000:.2f} km")
print(f"  Standard deviation             : {path_stats['Standard deviation (m)']/1000:.2f} km")
print(f"  Graph diameter (max obs.)      : {path_stats['Graph diameter (max shortest path, m)']/1000:.2f} km")
print()
print(f"  Reachable AA-AA pairs          : {n_reachable_pairs:,} / {n_possible_ordered_pairs:,} "
      f"({100*n_reachable_pairs/n_possible_ordered_pairs:.2f}%)")
print(f"  Unreachable AA-AA pairs        : {n_unreachable_pairs:,}")
print()
print("  Most central AA-AA junction  :",
      f"id={df_per_junction_sorted.iloc[0]['junction_id']:.0f}",
      f"(avg dist {df_per_junction_sorted.iloc[0]['average_distance']/1000:.1f} km)")
print("  Most isolated AA-AA junction :",
      f"id={df_per_junction_sorted.dropna(subset=['average_distance']).iloc[-1]['junction_id']:.0f}",
      f"(avg dist {df_per_junction_sorted.dropna(subset=['average_distance']).iloc[-1]['average_distance']/1000:.1f} km)")
print("=" * 65)
# Out:
# =================================================================
#   SRI LANKA ROAD NETWORK — AA-TO-AA JUNCTION DISTANCE EXPERIMENT
# =================================================================
#
#   Nodes (full graph, used for routing) : 5,557
#   Edges (road segments, full graph)    : 8,326
#   Connected components (full graph)    : 19
#   Average degree (full graph)          : 2.997
#   Graph density (full graph)           : 0.000539
#
#   AA-AA junctions analysed       : 83
#
#   Average shortest-path distance : 182.99 km
#   Median distance                : 179.59 km
#   Maximum distance               : 512.23 km
#   Minimum distance               : 0.01 km
#   Standard deviation             : 100.79 km
#   Graph diameter (max obs.)      : 512.23 km
#
#   Reachable AA-AA pairs          : 6,806 / 6,806 (100.00%)
#   Unreachable AA-AA pairs        : 0
#
#   Most central AA-AA junction  : id=6289622879 (avg dist 130.4 km)
#   Most isolated AA-AA junction : id=4136824665 (avg dist 278.9 km)
# =================================================================

# %% [markdown]
# ---
# ## 9. Research Questions — Answered from the Data Above
#
# 1. **How well connected is the AA road backbone?** See the reachable-pairs percentage in *Section 5/8b*
#    (note: connectivity relies on the full underlying road graph from *Section 2/3*, since AA-AA routes
#    may pass through non-AA roads).
# 2. **Average travel distance between two arbitrary AA-AA junctions?** `Mean shortest-path distance`
#    in *Section 5/8b*.
# 3. **Which AA-AA junctions are most central / remote?** *Section 6* and the heat maps in *Section 7c*.
# 4. **Which AA road corridors look isolated?** Red clusters on the heat map (*Section 7c*) and the tail of
#    the per-junction table sorted by `average_distance` (*Section 6*).
# 5. **How does the AA-AA subnetwork compare to the full network?** Compare the mean/median/95th-percentile
#    distance and the shape of the cumulative distribution (*Section 7d*) against the equivalent figures in
#    `experiment_all_junction_distance.ipynb` — a similar or lower mean distance suggests the AA backbone is
#    efficiently laid out relative to the wider road network.
#
# This per-junction CSV and pairwise distance table are saved so they can be reused directly for
# follow-up experiments: betweenness centrality, articulation-point detection, or comparisons against
# the AA-B or full-network baselines.
